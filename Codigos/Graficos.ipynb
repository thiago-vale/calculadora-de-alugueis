# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("aptos_csv2.csv")

# %%
sns.scatterplot(data=df.loc[df["crawler"].isin(["barra","copacabana", "tijuca" , "leblon"])], 
                x="area_limpo", 
                y="preço", 
                hue="crawler")
# Out:
# <AxesSubplot:xlabel='area_limpo', ylabel='preço'>

# %%
sns.displot(data=df.loc[df["crawler"].isin(["barra", "copacabana", "tijuca"])], 
            x="area_limpo", 
            hue="crawler")

# %%
df[['Quarto', 
    'Banheiro', 
    'Garagem', 
    'condominio', 
    'area_limpo', 
    'preço']].corr()
# Out:
#               Quarto  Banheiro   Garagem  condominio  area_limpo     preço
# Quarto      1.000000  0.625596  0.084733    0.015886    0.749508  0.326612
# Banheiro    0.625596  1.000000  0.066408    0.039736    0.670626  0.358406
# Garagem     0.084733  0.066408  1.000000   -0.000254    0.091104  0.088623
# condominio  0.015886  0.039736 -0.000254    1.000000    0.029315  0.028219
# area_limpo  0.749508  0.670626  0.091104    0.029315    1.000000  0.470181
# preço       0.326612  0.358406  0.088623    0.028219    0.470181  1.000000

# %%
df.columns
# Out:
# Index(['id', 'url', 'header', 'address', 'amenities', 'crawler', 'crawled_at',
#        'Quarto', 'Banheiro', 'Garagem', 'condominio', 'preço', 'area_limpo',
#        'Armário embutido', 'Quadra de tênis', 'Varanda gourmet',
#        'Armário embutido no quarto', 'Despensa', 'Elevador',
#        'Circuito de segurança', 'Lavabo', 'Porcelanato', 'Quintal',
#        'Aceita animais', 'Sala de massagem', 'Cozinha', 'Vista exterior',
#        'Espaço teen', 'Varanda', 'Sala grande', 'Sistema de alarme',
#        'Interfone', 'Próximo a escola', 'Churrasqueira na varanda',
#        'Isolamento térmico', 'Playground', 'Closet', 'Hall de entrada',
#        'Pista de cooper', 'Churrasqueira', 'Ambientes integrados',
#        'Aquecimento', 'Cabeamento estruturado', 'Piscina infantil',
#        'Vista para a montanha', 'Vista para o mar', 'Spa',
#        'Quadra poliesportiva', 'Ar-condicionado', 'Área de serviço', 'Sauna',
# ...

# %%
df["crawler"].unique()
# Out:
# array(['cachambi', 'rio_comprido', 'meier', 'tijuca', 'copacabana',
#        'ipanema', 'botafogo', 'leblon', 'recreio', 'jacarepaguá',
#        'taquara', 'barra'], dtype=object)

# %%
sns.jointplot(data=df.loc[df["crawler"].isin(["tijuca"])], 
              x="area_limpo", 
              y="preço", 
              hue="crawler")

# %%
plt.xticks(rotation=45)
sns.boxplot(data=df.loc[df["crawler"].isin(["leblon", "barra"])], 
            y="preço", 
            x="crawler")
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), [Text(0, 0, 'leblon'), Text(1, 0, 'barra')])

# %%
plt.xticks(rotation=45)
sns.boxplot(data=df.loc[df["crawler"].isin(["leblon", "barra" , "copacabana" , "tijuca"])], 
            y="preço", 
            x="crawler")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'tijuca'),
#   Text(1, 0, 'copacabana'),
#   Text(2, 0, 'leblon'),
#   Text(3, 0, 'barra')])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df.loc[df["crawler"].isin(["tijuca"])], 
            y="preço", 
            x="crawler")
plt.xticks(rotation=45)
# Out:
# (array([0]), [Text(0, 0, 'tijuca')])

# %%
df1 = df.loc[(df["crawler"]=="tijuca") & (df["preço"]<=1000) & (df["condominio"]<=1000) & (df["Quarto"]==1)]

# %%
df.loc[(df["crawler"]=="tijuca") & (df["preço"]<=1000) & (df["condominio"]<=1000) & (df["Quarto"]==1)].shape
# Out:
# (28, 97)

# %%
df.loc[(df["Quarto"]<=2)].shape
# Out:
# (4074, 97)

# %%
df.loc[(df["preço"]<=1000) & (df["condominio"]<=1000) & (df["Quarto"]<=2)].shape
# Out:
# (491, 97)

# %%
df.shape
# Out:
# (6946, 97)

# %%
df1["url"].to_csv("links2.csv", index=False)
